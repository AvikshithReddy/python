# %%
conda install pandas numpy
# Out:
# EnvironmentLocationNotFound: Not a conda environment: /Users/avikshithreddy/Documents/python
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
numbers = [x for x in range(5)]
numbers
# Out:
# [0, 1, 2, 3, 4]

# %%
position_experience_requirements = [1, 2, 3]

for x in position_experience_requirements:
    print(x)
# Out:
# 1
# 2
# 3

# %%
usser_experience = 4

# %%
qualified = [x for x in position_experience_requirements if usser_experience >= x]
qualified
# Out:
# [1, 2, 3]

# %%
pip install pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv("/Users/avikshithreddy/Desktop/data_jobs.csv")
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
job_title = df['job_title_short'].to_list().copy()
job_title
print(len(job_title))
# Out:
# 785741

# %%
job_title = [job for job in job_title if isinstance(job, str)]

# %%
len(job_title)
# Out:
# 785741

# %%
analyst_list = []
for job in job_title:
    if "Data Analyst" in job:
        analyst_list.append(job)
analyst_list
# Out:
# ['Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
# ...

# %%
print(len(analyst_list))
# Out:
# 225291

# %%
analyst_list = [job for job in job_title if "Data Analyst" in job]

# %%
print(len(analyst_list))
# Out:
# 225291
